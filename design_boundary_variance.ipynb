# %%
import pandas as pd
import numpy as np

from matal.recipe import UniformCompositionGenerator

# %% [markdown]
# ## 1. Generate compositions within design space using variance sampling

# %% [markdown]
# ### (1) Define available materials

# %%
materials = ['LAP', 'MMT', 'CMC', 'CNF', 'SLK',
             'AGR', 'ALG', 'CAR', 'CHS', 'PEC', 'PUL', 'STA', 'GEL', 'GLU', 'ZIN',
             'GLY', 'FFA', 'LAC', 'LEV', 'PHA', 'SRB', 'SUA', 'XYL']
len(materials)
# Out:
# 23

# %% [markdown]
# ### (2) Load current model

# %%
from models import gen_pred_df, MODELS
MODELS
# Out:
# {'pt_db.v3hp.RE5C': StackedModel(
#    (models): ModuleDict(
#      (encoder): ANNModel(
#        (layers): ModuleDict(
#          (fc1): Linear(in_features=23, out_features=360, bias=True)
#          (fc1_act): ELU(alpha=1.0)
#          (fc2): Linear(in_features=360, out_features=345, bias=True)
#          (fc2_act): ELU(alpha=1.0)
#          (fc3): Linear(in_features=345, out_features=337, bias=True)
#          (fc3_act): ELU(alpha=1.0)
#          (fc4): Linear(in_features=337, out_features=330, bias=True)
#          (fc4_act): ELU(alpha=1.0)
#          (fc5): Linear(in_features=330, out_features=322, bias=True)
#          (fc5_act): ELU(alpha=1.0)
#          (fc6): Linear(in_features=322, out_features=314, bias=True)
#          (fc6_act): ELU(alpha=1.0)
#          (fc7): Linear(in_features=314, out_features=307, bias=True)
#          (fc7_act): ELU(alpha=1.0)
#          (fc8): Linear(in_features=307, out_features=299, bias=True)
#          (fc8_act): ELU(alpha=1.0)
#          (fc9): Linear(in_features=299, out_features=291, bias=True)
#          (fc9_act): ELU(alpha=1.0)
#          (fc10): Linear(in_features=291, out_features=284, bias=True)
#          (fc10_act): ELU(alpha=1.0)
#          (fc11): Linear(in_features=284, out_features=276, bias=True)
#          (fc11_act): ELU(alpha=1.0)
#          (fc12): Linear(in_features=276, out_features=268, bias=True)
#          (fc12_act): ELU(alpha=1.0)
#          (fc13): Linear(in_features=268, out_features=261, bias=True)
#          (fc13_act): ELU(alpha=1.0)
#          (fc14): Linear(in_features=261, out_features=253, bias=True)
#          (fc14_act): ELU(alpha=1.0)
#          (fc15): Linear(in_features=253, out_features=245, bias=True)
#          (fc15_act): ELU(alpha=1.0)
#          (fc16): Linear(in_features=245, out_features=238, bias=True)
#          (fc16_act): ELU(alpha=1.0)
#          (fc17): Linear(in_features=238, out_features=230, bias=True)
#          (fc17_act): ELU(alpha=1.0)
#          (fc18): Linear(in_features=230, out_features=222, bias=True)
#          (fc18_act): ELU(alpha=1.0)
#          (fc19): Linear(in_features=222, out_features=214, bias=True)
#          (fc19_act): ELU(alpha=1.0)
#          (fc20): Linear(in_features=214, out_features=206, bias=True)
#          (fc20_act): ELU(alpha=1.0)
#          (fc21): Linear(in_features=206, out_features=199, bias=True)
#          (fc21_act): ELU(alpha=1.0)
#          (fc22): Linear(in_features=199, out_features=191, bias=True)
#          (fc22_act): ELU(alpha=1.0)
#          (fc23): Linear(in_features=191, out_features=183, bias=True)
#          (fc23_act): ELU(alpha=1.0)
#          (fc24): Linear(in_features=183, out_features=175, bias=True)
#          (fc24_act): ELU(alpha=1.0)
#          (fc25): Linear(in_features=175, out_features=167, bias=True)
#          (fc25_act): ELU(alpha=1.0)
#          (fc26): Linear(in_features=167, out_features=160, bias=True)
#          (fc26_act): ELU(alpha=1.0)
#          (fc27): Linear(in_features=160, out_features=152, bias=True)
#          (fc27_act): ELU(alpha=1.0)
#          (fc28): Linear(in_features=152, out_features=144, bias=True)
#          (fc28_act): ELU(alpha=1.0)
#          (fc29): Linear(in_features=144, out_features=136, bias=True)
#          (fc29_act): ELU(alpha=1.0)
#          (fc30): Linear(in_features=136, out_features=128, bias=True)
#          (fc30_act): Identity()
#        )
#      )
#      (grade): ANNModel(
#        (layers): ModuleDict(
#          (fc1): Linear(in_features=128, out_features=5, bias=True)
#          (fc1_act): ELU(alpha=1.0)
#          (fc2): Linear(in_features=5, out_features=3, bias=True)
#          (fc2_act): Sigmoid()
#        )
#      )
#      (optical): ANNModel(
#        (layers): ModuleDict(
#          (fc1): Linear(in_features=128, out_features=5, bias=True)
#          (fc1_act): ELU(alpha=1.0)
#          (fc2): Linear(in_features=5, out_features=3, bias=True)
#          (fc2_act): Sigmoid()
#        )
#      )
#      (tensile): ANNModel(
#        (layers): ModuleDict(
#          (fc1): Linear(in_features=128, out_features=6, bias=True)
#          (fc1_act): ELU(alpha=1.0)
#          (fc2): Linear(in_features=6, out_features=4, bias=True)
#          (fc2_act): ReLU()
#        )
#      )
#      (fire): ANNModel(
#        (layers): ModuleDict(
#          (fc1): Linear(in_features=128, out_features=3, bias=True)
#          (fc1_act): ELU(alpha=1.0)
#          (fc2): Linear(in_features=3, out_features=1, bias=True)
#          (fc2_act): Sigmoid()
#        )
#      )
#    )
#  ),
#  'pt_db.v3hp.VPLV': StackedModel(
#    (models): ModuleDict(
#      (encoder): ANNModel(
#        (layers): ModuleDict(
#          (fc1): Linear(in_features=23, out_features=360, bias=True)
#          (fc1_act): ELU(alpha=1.0)
#          (fc2): Linear(in_features=360, out_features=349, bias=True)
#          (fc2_act): ELU(alpha=1.0)
#          (fc3): Linear(in_features=349, out_features=343, bias=True)
#          (fc3_act): ELU(alpha=1.0)
#          (fc4): Linear(in_features=343, out_features=337, bias=True)
#          (fc4_act): ELU(alpha=1.0)
#          (fc5): Linear(in_features=337, out_features=332, bias=True)
#          (fc5_act): ELU(alpha=1.0)
#          (fc6): Linear(in_features=332, out_features=326, bias=True)
#          (fc6_act): ELU(alpha=1.0)
#          (fc7): Linear(in_features=326, out_features=320, bias=True)
#          (fc7_act): ELU(alpha=1.0)
#          (fc8): Linear(in_features=320, out_features=314, bias=True)
#          (fc8_act): ELU(alpha=1.0)
#          (fc9): Linear(in_features=314, out_features=309, bias=True)
#          (fc9_act): ELU(alpha=1.0)
#          (fc10): Linear(in_features=309, out_features=303, bias=True)
#          (fc10_act): ELU(alpha=1.0)
#          (fc11): Linear(in_features=303, out_features=297, bias=True)
#          (fc11_act): ELU(alpha=1.0)
#          (fc12): Linear(in_features=297, out_features=291, bias=True)
#          (fc12_act): ELU(alpha=1.0)
#          (fc13): Linear(in_features=291, out_features=286, bias=True)
#          (fc13_act): ELU(alpha=1.0)
#          (fc14): Linear(in_features=286, out_features=280, bias=True)
#          (fc14_act): ELU(alpha=1.0)
#          (fc15): Linear(in_features=280, out_features=274, bias=True)
#          (fc15_act): ELU(alpha=1.0)
#          (fc16): Linear(in_features=274, out_features=268, bias=True)
#          (fc16_act): ELU(alpha=1.0)
#          (fc17): Linear(in_features=268, out_features=263, bias=True)
#          (fc17_act): ELU(alpha=1.0)
#          (fc18): Linear(in_features=263, out_features=257, bias=True)
#          (fc18_act): ELU(alpha=1.0)
#          (fc19): Linear(in_features=257, out_features=251, bias=True)
#          (fc19_act): ELU(alpha=1.0)
#          (fc20): Linear(in_features=251, out_features=245, bias=True)
#          (fc20_act): ELU(alpha=1.0)
#          (fc21): Linear(in_features=245, out_features=239, bias=True)
#          (fc21_act): ELU(alpha=1.0)
#          (fc22): Linear(in_features=239, out_features=234, bias=True)
#          (fc22_act): ELU(alpha=1.0)
#          (fc23): Linear(in_features=234, out_features=228, bias=True)
#          (fc23_act): ELU(alpha=1.0)
#          (fc24): Linear(in_features=228, out_features=222, bias=True)
#          (fc24_act): ELU(alpha=1.0)
#          (fc25): Linear(in_features=222, out_features=216, bias=True)
#          (fc25_act): ELU(alpha=1.0)
#          (fc26): Linear(in_features=216, out_features=210, bias=True)
#          (fc26_act): ELU(alpha=1.0)
#          (fc27): Linear(in_features=210, out_features=205, bias=True)
#          (fc27_act): ELU(alpha=1.0)
#          (fc28): Linear(in_features=205, out_features=199, bias=True)
#          (fc28_act): ELU(alpha=1.0)
#          (fc29): Linear(in_features=199, out_features=193, bias=True)
#          (fc29_act): ELU(alpha=1.0)
#          (fc30): Linear(in_features=193, out_features=187, bias=True)
#          (fc30_act): ELU(alpha=1.0)
#          (fc31): Linear(in_features=187, out_features=181, bias=True)
#          (fc31_act): ELU(alpha=1.0)
#          (fc32): Linear(in_features=181, out_features=175, bias=True)
#          (fc32_act): ELU(alpha=1.0)
#          (fc33): Linear(in_features=175, out_features=169, bias=True)
#          (fc33_act): ELU(alpha=1.0)
#          (fc34): Linear(in_features=169, out_features=163, bias=True)
#          (fc34_act): ELU(alpha=1.0)
#          (fc35): Linear(in_features=163, out_features=158, bias=True)
#          (fc35_act): ELU(alpha=1.0)
#          (fc36): Linear(in_features=158, out_features=152, bias=True)
#          (fc36_act): ELU(alpha=1.0)
#          (fc37): Linear(in_features=152, out_features=146, bias=True)
#          (fc37_act): ELU(alpha=1.0)
#          (fc38): Linear(in_features=146, out_features=140, bias=True)
#          (fc38_act): ELU(alpha=1.0)
#          (fc39): Linear(in_features=140, out_features=134, bias=True)
#          (fc39_act): ELU(alpha=1.0)
#          (fc40): Linear(in_features=134, out_features=128, bias=True)
#          (fc40_act): Identity()
#        )
#      )
#      (grade): ANNModel(
#        (layers): ModuleDict(
#          (fc1): Linear(in_features=128, out_features=7, bias=True)
#          (fc1_act): ELU(alpha=1.0)
#          (fc2): Linear(in_features=7, out_features=5, bias=True)
#          (fc2_act): ELU(alpha=1.0)
#          (fc3): Linear(in_features=5, out_features=3, bias=True)
#          (fc3_act): Sigmoid()
#        )
#      )
#      (optical): ANNModel(
#        (layers): ModuleDict(
#          (fc1): Linear(in_features=128, out_features=7, bias=True)
#          (fc1_act): ELU(alpha=1.0)
#          (fc2): Linear(in_features=7, out_features=5, bias=True)
#          (fc2_act): ELU(alpha=1.0)
#          (fc3): Linear(in_features=5, out_features=3, bias=True)
#          (fc3_act): Sigmoid()
#        )
#      )
#      (tensile): ANNModel(
#        (layers): ModuleDict(
#          (fc1): Linear(in_features=128, out_features=8, bias=True)
#          (fc1_act): ELU(alpha=1.0)
#          (fc2): Linear(in_features=8, out_features=6, bias=True)
#          (fc2_act): ELU(alpha=1.0)
#          (fc3): Linear(in_features=6, out_features=4, bias=True)
#          (fc3_act): ReLU()
#        )
#      )
#      (fire): ANNModel(
#        (layers): ModuleDict(
#          (fc1): Linear(in_features=128, out_features=5, bias=True)
#          (fc1_act): ELU(alpha=1.0)
#          (fc2): Linear(in_features=5, out_features=3, bias=True)
#          (fc2_act): ELU(alpha=1.0)
#          (fc3): Linear(in_features=3, out_features=1, bias=True)
#          (fc3_act): Sigmoid()
#        )
#      )
#    )
#  ),
#  'pt_db.v3hp.PFFZ': StackedModel(
#    (models): ModuleDict(
#      (encoder): ANNModel(
#        (layers): ModuleDict(
#          (fc1): Linear(in_features=23, out_features=400, bias=True)
#          (fc1_act): ELU(alpha=1.0)
#          (fc2): Linear(in_features=400, out_features=387, bias=True)
#          (fc2_act): ELU(alpha=1.0)
#          (fc3): Linear(in_features=387, out_features=380, bias=True)
#          (fc3_act): ELU(alpha=1.0)
#          (fc4): Linear(in_features=380, out_features=373, bias=True)
#          (fc4_act): ELU(alpha=1.0)
#          (fc5): Linear(in_features=373, out_features=367, bias=True)
#          (fc5_act): ELU(alpha=1.0)
#          (fc6): Linear(in_features=367, out_features=360, bias=True)
#          (fc6_act): ELU(alpha=1.0)
#          (fc7): Linear(in_features=360, out_features=353, bias=True)
#          (fc7_act): ELU(alpha=1.0)
#          (fc8): Linear(in_features=353, out_features=347, bias=True)
#          (fc8_act): ELU(alpha=1.0)
#          (fc9): Linear(in_features=347, out_features=340, bias=True)
#          (fc9_act): ELU(alpha=1.0)
#          (fc10): Linear(in_features=340, out_features=333, bias=True)
#          (fc10_act): ELU(alpha=1.0)
#          (fc11): Linear(in_features=333, out_features=327, bias=True)
#          (fc11_act): ELU(alpha=1.0)
#          (fc12): Linear(in_features=327, out_features=320, bias=True)
#          (fc12_act): ELU(alpha=1.0)
#          (fc13): Linear(in_features=320, out_features=313, bias=True)
#          (fc13_act): ELU(alpha=1.0)
#          (fc14): Linear(in_features=313, out_features=306, bias=True)
#          (fc14_act): ELU(alpha=1.0)
#          (fc15): Linear(in_features=306, out_features=300, bias=True)
#          (fc15_act): ELU(alpha=1.0)
#          (fc16): Linear(in_features=300, out_features=293, bias=True)
#          (fc16_act): ELU(alpha=1.0)
#          (fc17): Linear(in_features=293, out_features=286, bias=True)
#          (fc17_act): ELU(alpha=1.0)
#          (fc18): Linear(in_features=286, out_features=279, bias=True)
#          (fc18_act): ELU(alpha=1.0)
#          (fc19): Linear(in_features=279, out_features=273, bias=True)
#          (fc19_act): ELU(alpha=1.0)
#          (fc20): Linear(in_features=273, out_features=266, bias=True)
#          (fc20_act): ELU(alpha=1.0)
#          (fc21): Linear(in_features=266, out_features=259, bias=True)
#          (fc21_act): ELU(alpha=1.0)
#          (fc22): Linear(in_features=259, out_features=252, bias=True)
#          (fc22_act): ELU(alpha=1.0)
#          (fc23): Linear(in_features=252, out_features=245, bias=True)
#          (fc23_act): ELU(alpha=1.0)
#          (fc24): Linear(in_features=245, out_features=239, bias=True)
#          (fc24_act): ELU(alpha=1.0)
#          (fc25): Linear(in_features=239, out_features=232, bias=True)
#          (fc25_act): ELU(alpha=1.0)
#          (fc26): Linear(in_features=232, out_features=225, bias=True)
#          (fc26_act): ELU(alpha=1.0)
#          (fc27): Linear(in_features=225, out_features=218, bias=True)
#          (fc27_act): ELU(alpha=1.0)
#          (fc28): Linear(in_features=218, out_features=211, bias=True)
#          (fc28_act): ELU(alpha=1.0)
#          (fc29): Linear(in_features=211, out_features=204, bias=True)
#          (fc29_act): ELU(alpha=1.0)
#          (fc30): Linear(in_features=204, out_features=197, bias=True)
#          (fc30_act): ELU(alpha=1.0)
#          (fc31): Linear(in_features=197, out_features=190, bias=True)
#          (fc31_act): ELU(alpha=1.0)
#          (fc32): Linear(in_features=190, out_features=184, bias=True)
#          (fc32_act): ELU(alpha=1.0)
#          (fc33): Linear(in_features=184, out_features=177, bias=True)
#          (fc33_act): ELU(alpha=1.0)
#          (fc34): Linear(in_features=177, out_features=170, bias=True)
#          (fc34_act): ELU(alpha=1.0)
#          (fc35): Linear(in_features=170, out_features=163, bias=True)
#          (fc35_act): ELU(alpha=1.0)
#          (fc36): Linear(in_features=163, out_features=156, bias=True)
#          (fc36_act): ELU(alpha=1.0)
#          (fc37): Linear(in_features=156, out_features=149, bias=True)
#          (fc37_act): ELU(alpha=1.0)
#          (fc38): Linear(in_features=149, out_features=142, bias=True)
#          (fc38_act): ELU(alpha=1.0)
#          (fc39): Linear(in_features=142, out_features=135, bias=True)
#          (fc39_act): ELU(alpha=1.0)
#          (fc40): Linear(in_features=135, out_features=128, bias=True)
#          (fc40_act): Identity()
#        )
#      )
#      (grade): ANNModel(
#        (layers): ModuleDict(
#          (fc1): Linear(in_features=128, out_features=7, bias=True)
#          (fc1_act): ELU(alpha=1.0)
#          (fc2): Linear(in_features=7, out_features=5, bias=True)
#          (fc2_act): ELU(alpha=1.0)
#          (fc3): Linear(in_features=5, out_features=3, bias=True)
#          (fc3_act): Sigmoid()
#        )
#      )
#      (optical): ANNModel(
#        (layers): ModuleDict(
#          (fc1): Linear(in_features=128, out_features=7, bias=True)
#          (fc1_act): ELU(alpha=1.0)
#          (fc2): Linear(in_features=7, out_features=5, bias=True)
#          (fc2_act): ELU(alpha=1.0)
#          (fc3): Linear(in_features=5, out_features=3, bias=True)
#          (fc3_act): Sigmoid()
#        )
#      )
#      (tensile): ANNModel(
#        (layers): ModuleDict(
#          (fc1): Linear(in_features=128, out_features=8, bias=True)
#          (fc1_act): ELU(alpha=1.0)
#          (fc2): Linear(in_features=8, out_features=6, bias=True)
#          (fc2_act): ELU(alpha=1.0)
#          (fc3): Linear(in_features=6, out_features=4, bias=True)
#          (fc3_act): ReLU()
#        )
#      )
#      (fire): ANNModel(
#        (layers): ModuleDict(
#          (fc1): Linear(in_features=128, out_features=5, bias=True)
#          (fc1_act): ELU(alpha=1.0)
#          (fc2): Linear(in_features=5, out_features=3, bias=True)
#          (fc2_act): ELU(alpha=1.0)
#          (fc3): Linear(in_features=3, out_features=1, bias=True)
#          (fc3_act): Sigmoid()
#        )
#      )
#    )
#  ),
#  'pt_db.v3hp.CPUT': StackedModel(
#    (models): ModuleDict(
#      (encoder): ANNModel(
#        (layers): ModuleDict(
#          (fc1): Linear(in_features=23, out_features=320, bias=True)
#          (fc1_act): ELU(alpha=1.0)
#          (fc2): Linear(in_features=320, out_features=312, bias=True)
#          (fc2_act): ELU(alpha=1.0)
#          (fc3): Linear(in_features=312, out_features=309, bias=True)
#          (fc3_act): ELU(alpha=1.0)
#          (fc4): Linear(in_features=309, out_features=305, bias=True)
#          (fc4_act): ELU(alpha=1.0)
#          (fc5): Linear(in_features=305, out_features=301, bias=True)
#          (fc5_act): ELU(alpha=1.0)
#          (fc6): Linear(in_features=301, out_features=297, bias=True)
#          (fc6_act): ELU(alpha=1.0)
#          (fc7): Linear(in_features=297, out_features=294, bias=True)
#          (fc7_act): ELU(alpha=1.0)
#          (fc8): Linear(in_features=294, out_features=290, bias=True)
#          (fc8_act): ELU(alpha=1.0)
#          (fc9): Linear(in_features=290, out_features=286, bias=True)
#          (fc9_act): ELU(alpha=1.0)
#          (fc10): Linear(in_features=286, out_features=282, bias=True)
#          (fc10_act): ELU(alpha=1.0)
#          (fc11): Linear(in_features=282, out_features=278, bias=True)
#          (fc11_act): ELU(alpha=1.0)
#          (fc12): Linear(in_features=278, out_features=275, bias=True)
#          (fc12_act): ELU(alpha=1.0)
#          (fc13): Linear(in_features=275, out_features=271, bias=True)
#          (fc13_act): ELU(alpha=1.0)
#          (fc14): Linear(in_features=271, out_features=267, bias=True)
#          (fc14_act): ELU(alpha=1.0)
#          (fc15): Linear(in_features=267, out_features=263, bias=True)
#          (fc15_act): ELU(alpha=1.0)
#          (fc16): Linear(in_features=263, out_features=259, bias=True)
#          (fc16_act): ELU(alpha=1.0)
#          (fc17): Linear(in_features=259, out_features=256, bias=True)
#          (fc17_act): ELU(alpha=1.0)
#          (fc18): Linear(in_features=256, out_features=252, bias=True)
#          (fc18_act): ELU(alpha=1.0)
#          (fc19): Linear(in_features=252, out_features=248, bias=True)
#          (fc19_act): ELU(alpha=1.0)
#          (fc20): Linear(in_features=248, out_features=244, bias=True)
#          (fc20_act): ELU(alpha=1.0)
#          (fc21): Linear(in_features=244, out_features=240, bias=True)
#          (fc21_act): ELU(alpha=1.0)
#          (fc22): Linear(in_features=240, out_features=236, bias=True)
#          (fc22_act): ELU(alpha=1.0)
#          (fc23): Linear(in_features=236, out_features=233, bias=True)
#          (fc23_act): ELU(alpha=1.0)
#          (fc24): Linear(in_features=233, out_features=229, bias=True)
#          (fc24_act): ELU(alpha=1.0)
#          (fc25): Linear(in_features=229, out_features=225, bias=True)
#          (fc25_act): ELU(alpha=1.0)
#          (fc26): Linear(in_features=225, out_features=221, bias=True)
#          (fc26_act): ELU(alpha=1.0)
#          (fc27): Linear(in_features=221, out_features=217, bias=True)
#          (fc27_act): ELU(alpha=1.0)
#          (fc28): Linear(in_features=217, out_features=213, bias=True)
#          (fc28_act): ELU(alpha=1.0)
#          (fc29): Linear(in_features=213, out_features=210, bias=True)
#          (fc29_act): ELU(alpha=1.0)
#          (fc30): Linear(in_features=210, out_features=206, bias=True)
#          (fc30_act): ELU(alpha=1.0)
#          (fc31): Linear(in_features=206, out_features=202, bias=True)
#          (fc31_act): ELU(alpha=1.0)
#          (fc32): Linear(in_features=202, out_features=198, bias=True)
#          (fc32_act): ELU(alpha=1.0)
#          (fc33): Linear(in_features=198, out_features=194, bias=True)
#          (fc33_act): ELU(alpha=1.0)
#          (fc34): Linear(in_features=194, out_features=190, bias=True)
#          (fc34_act): ELU(alpha=1.0)
#          (fc35): Linear(in_features=190, out_features=186, bias=True)
#          (fc35_act): ELU(alpha=1.0)
#          (fc36): Linear(in_features=186, out_features=182, bias=True)
#          (fc36_act): ELU(alpha=1.0)
#          (fc37): Linear(in_features=182, out_features=179, bias=True)
#          (fc37_act): ELU(alpha=1.0)
#          (fc38): Linear(in_features=179, out_features=175, bias=True)
#          (fc38_act): ELU(alpha=1.0)
#          (fc39): Linear(in_features=175, out_features=171, bias=True)
#          (fc39_act): ELU(alpha=1.0)
#          (fc40): Linear(in_features=171, out_features=167, bias=True)
#          (fc40_act): ELU(alpha=1.0)
#          (fc41): Linear(in_features=167, out_features=163, bias=True)
#          (fc41_act): ELU(alpha=1.0)
#          (fc42): Linear(in_features=163, out_features=159, bias=True)
#          (fc42_act): ELU(alpha=1.0)
#          (fc43): Linear(in_features=159, out_features=155, bias=True)
#          (fc43_act): ELU(alpha=1.0)
#          (fc44): Linear(in_features=155, out_features=151, bias=True)
#          (fc44_act): ELU(alpha=1.0)
#          (fc45): Linear(in_features=151, out_features=148, bias=True)
#          (fc45_act): ELU(alpha=1.0)
#          (fc46): Linear(in_features=148, out_features=144, bias=True)
#          (fc46_act): ELU(alpha=1.0)
#          (fc47): Linear(in_features=144, out_features=140, bias=True)
#          (fc47_act): ELU(alpha=1.0)
#          (fc48): Linear(in_features=140, out_features=136, bias=True)
#          (fc48_act): ELU(alpha=1.0)
#          (fc49): Linear(in_features=136, out_features=132, bias=True)
#          (fc49_act): ELU(alpha=1.0)
#          (fc50): Linear(in_features=132, out_features=128, bias=True)
#          (fc50_act): Identity()
#        )
#      )
#      (grade): ANNModel(
#        (layers): ModuleDict(
#          (fc1): Linear(in_features=128, out_features=7, bias=True)
#          (fc1_act): ELU(alpha=1.0)
#          (fc2): Linear(in_features=7, out_features=5, bias=True)
#          (fc2_act): ELU(alpha=1.0)
#          (fc3): Linear(in_features=5, out_features=3, bias=True)
#          (fc3_act): Sigmoid()
#        )
#      )
#      (optical): ANNModel(
#        (layers): ModuleDict(
#          (fc1): Linear(in_features=128, out_features=7, bias=True)
#          (fc1_act): ELU(alpha=1.0)
#          (fc2): Linear(in_features=7, out_features=5, bias=True)
#          (fc2_act): ELU(alpha=1.0)
#          (fc3): Linear(in_features=5, out_features=3, bias=True)
#          (fc3_act): Sigmoid()
#        )
#      )
#      (tensile): ANNModel(
#        (layers): ModuleDict(
#          (fc1): Linear(in_features=128, out_features=8, bias=True)
#          (fc1_act): ELU(alpha=1.0)
#          (fc2): Linear(in_features=8, out_features=6, bias=True)
#          (fc2_act): ELU(alpha=1.0)
#          (fc3): Linear(in_features=6, out_features=4, bias=True)
#          (fc3_act): ReLU()
#        )
#      )
#      (fire): ANNModel(
#        (layers): ModuleDict(
#          (fc1): Linear(in_features=128, out_features=5, bias=True)
#          (fc1_act): ELU(alpha=1.0)
#          (fc2): Linear(in_features=5, out_features=3, bias=True)
#          (fc2_act): ELU(alpha=1.0)
#          (fc3): Linear(in_features=3, out_features=1, bias=True)
#          (fc3_act): Sigmoid()
#        )
#      )
#    )
#  ),
#  'pt_db.v3hp.2HNP': StackedModel(
#    (models): ModuleDict(
#      (encoder): ANNModel(
#        (layers): ModuleDict(
#          (fc1): Linear(in_features=23, out_features=320, bias=True)
#          (fc1_act): ELU(alpha=1.0)
#          (fc2): Linear(in_features=320, out_features=307, bias=True)
#          (fc2_act): ELU(alpha=1.0)
#          (fc3): Linear(in_features=307, out_features=301, bias=True)
#          (fc3_act): ELU(alpha=1.0)
#          (fc4): Linear(in_features=301, out_features=295, bias=True)
#          (fc4_act): ELU(alpha=1.0)
#          (fc5): Linear(in_features=295, out_features=288, bias=True)
#          (fc5_act): ELU(alpha=1.0)
#          (fc6): Linear(in_features=288, out_features=282, bias=True)
#          (fc6_act): ELU(alpha=1.0)
#          (fc7): Linear(in_features=282, out_features=276, bias=True)
#          (fc7_act): ELU(alpha=1.0)
#          (fc8): Linear(in_features=276, out_features=269, bias=True)
#          (fc8_act): ELU(alpha=1.0)
#          (fc9): Linear(in_features=269, out_features=263, bias=True)
#          (fc9_act): ELU(alpha=1.0)
#          (fc10): Linear(in_features=263, out_features=257, bias=True)
#          (fc10_act): ELU(alpha=1.0)
#          (fc11): Linear(in_features=257, out_features=250, bias=True)
#          (fc11_act): ELU(alpha=1.0)
#          (fc12): Linear(in_features=250, out_features=244, bias=True)
#          (fc12_act): ELU(alpha=1.0)
#          (fc13): Linear(in_features=244, out_features=238, bias=True)
#          (fc13_act): ELU(alpha=1.0)
#          (fc14): Linear(in_features=238, out_features=231, bias=True)
#          (fc14_act): ELU(alpha=1.0)
#          (fc15): Linear(in_features=231, out_features=225, bias=True)
#          (fc15_act): ELU(alpha=1.0)
#          (fc16): Linear(in_features=225, out_features=218, bias=True)
#          (fc16_act): ELU(alpha=1.0)
#          (fc17): Linear(in_features=218, out_features=212, bias=True)
#          (fc17_act): ELU(alpha=1.0)
#          (fc18): Linear(in_features=212, out_features=206, bias=True)
#          (fc18_act): ELU(alpha=1.0)
#          (fc19): Linear(in_features=206, out_features=199, bias=True)
#          (fc19_act): ELU(alpha=1.0)
#          (fc20): Linear(in_features=199, out_features=193, bias=True)
#          (fc20_act): ELU(alpha=1.0)
#          (fc21): Linear(in_features=193, out_features=186, bias=True)
#          (fc21_act): ELU(alpha=1.0)
#          (fc22): Linear(in_features=186, out_features=180, bias=True)
#          (fc22_act): ELU(alpha=1.0)
#          (fc23): Linear(in_features=180, out_features=173, bias=True)
#          (fc23_act): ELU(alpha=1.0)
#          (fc24): Linear(in_features=173, out_features=167, bias=True)
#          (fc24_act): ELU(alpha=1.0)
#          (fc25): Linear(in_features=167, out_features=160, bias=True)
#          (fc25_act): ELU(alpha=1.0)
#          (fc26): Linear(in_features=160, out_features=154, bias=True)
#          (fc26_act): ELU(alpha=1.0)
#          (fc27): Linear(in_features=154, out_features=148, bias=True)
#          (fc27_act): ELU(alpha=1.0)
#          (fc28): Linear(in_features=148, out_features=141, bias=True)
#          (fc28_act): ELU(alpha=1.0)
#          (fc29): Linear(in_features=141, out_features=135, bias=True)
#          (fc29_act): ELU(alpha=1.0)
#          (fc30): Linear(in_features=135, out_features=128, bias=True)
#          (fc30_act): Identity()
#        )
#      )
#      (grade): ANNModel(
#        (layers): ModuleDict(
#          (fc1): Linear(in_features=128, out_features=5, bias=True)
#          (fc1_act): ELU(alpha=1.0)
#          (fc2): Linear(in_features=5, out_features=3, bias=True)
#          (fc2_act): Sigmoid()
#        )
#      )
#      (optical): ANNModel(
#        (layers): ModuleDict(
#          (fc1): Linear(in_features=128, out_features=5, bias=True)
#          (fc1_act): ELU(alpha=1.0)
#          (fc2): Linear(in_features=5, out_features=3, bias=True)
#          (fc2_act): Sigmoid()
#        )
#      )
#      (tensile): ANNModel(
#        (layers): ModuleDict(
#          (fc1): Linear(in_features=128, out_features=6, bias=True)
#          (fc1_act): ELU(alpha=1.0)
#          (fc2): Linear(in_features=6, out_features=4, bias=True)
#          (fc2_act): ReLU()
#        )
#      )
#      (fire): ANNModel(
#        (layers): ModuleDict(
#          (fc1): Linear(in_features=128, out_features=3, bias=True)
#          (fc1_act): ELU(alpha=1.0)
#          (fc2): Linear(in_features=3, out_features=1, bias=True)
#          (fc2_act): Sigmoid()
#        )
#      )
#    )
#  )}

# %%
def feasibility_variance(comps):
    return gen_pred_df(comps, targets=['grade'])['Feasibility_STD']

# %% [markdown]
# ### (3) Generate uniform compositions

# %%
ucg = UniformCompositionGenerator(materials=materials,
                                  n_comps=150,
                                  n_iters=1_000_000,
                                  n_sources_per_comp=5,
                                  perf_func=feasibility_variance,
                                  min_frac=0.025,
                                  )
new_batch = ucg.optimize()
new_batch
# Out:
#   0%|          | 0/1000000 [00:00<?, ?it/s]
#           LAP       MMT       CMC  CNF  SLK  AGR       ALG       CAR  \
# 0    0.000000  0.189236  0.000000  0.0  0.0  0.0  0.048915  0.159866
# 1    0.000000  0.224394  0.305912  0.0  0.0  0.0  0.000000  0.000000
# 2    0.000000  0.000000  0.123941  0.0  0.0  0.0  0.213227  0.000000
# 3    0.000000  0.000000  0.000000  0.0  0.0  0.0  0.000000  0.000000
# 4    0.000000  0.275895  0.000000  0.0  0.0  0.0  0.000000  0.000000
# ..        ...       ...       ...  ...  ...  ...       ...       ...
# 145  0.077455  0.000000  0.167788  0.0  0.0  0.0  0.000000  0.032011
# 146  0.329196  0.182367  0.000000  0.0  0.0  0.0  0.000000  0.000000
# 147  0.000000  0.000000  0.213467  0.0  0.0  0.0  0.000000  0.222226
# 148  0.285960  0.000000  0.000000  0.0  0.0  0.0  0.122789  0.000000
# 149  0.000000  0.000000  0.000000  0.0  0.0  0.0  0.000000  0.000000
#
#           CHS       PEC  ...       GLU       ZIN       GLY       FFA  \
# 0    0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 1    0.177051  0.000000  ...  0.226788  0.000000  0.000000  0.000000
# 2    0.000000  0.048898  ...  0.000000  0.000000  0.000000  0.000000
# 3    0.000000  0.092687  ...  0.000000  0.075001  0.000000  0.000000
# 4    0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# ..        ...       ...  ...       ...       ...       ...       ...
# 145  0.000000  0.000000  ...  0.000000  0.000000  0.426636  0.000000
# 146  0.000000  0.053124  ...  0.000000  0.000000  0.000000  0.000000
# 147  0.000000  0.000000  ...  0.116013  0.000000  0.000000  0.276047
# 148  0.041182  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 149  0.260688  0.000000  ...  0.000000  0.000000  0.000000  0.000000
#
#           LAC       LEV       PHA       SRB       SUA       XYL
# 0    0.282600  0.000000  0.000000  0.319384  0.000000  0.000000
# 1    0.000000  0.000000  0.000000  0.000000  0.000000  0.065855
# 2    0.000000  0.000000  0.304002  0.000000  0.000000  0.000000
# 3    0.000000  0.000000  0.291286  0.352867  0.000000  0.188159
# 4    0.000000  0.026967  0.328145  0.000000  0.157773  0.211220
# ..        ...       ...       ...       ...       ...       ...
# 145  0.296109  0.000000  0.000000  0.000000  0.000000  0.000000
# 146  0.000000  0.000000  0.000000  0.000000  0.227462  0.000000
# 147  0.000000  0.000000  0.000000  0.000000  0.172246  0.000000
# 148  0.215113  0.000000  0.000000  0.334956  0.000000  0.000000
# 149  0.000000  0.000000  0.422960  0.000000  0.138097  0.000000
#
# [150 rows x 23 columns]
